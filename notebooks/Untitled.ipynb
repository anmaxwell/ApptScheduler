# %%
import pandas
df = pandas.read_csv('GP_APPT_Publication_January _2022.csv')
print(df)
# Out:
#    Appointment_Date Total Count of Appointments Face-to-Face Home Visit  \
# 0         01-Jan-22                       4,383        3,034         99
# 1         02-Jan-22                       4,402        2,788         66
# 2         03-Jan-22                       7,513        5,707         33
# 3         04-Jan-22                   1,296,365      765,296      9,734
# 4         05-Jan-22                   1,235,616      738,707      9,004
# 5         06-Jan-22                   1,218,180      731,037      8,629
# 6         07-Jan-22                   1,172,400      692,900      6,905
# 7         08-Jan-22                      38,695       27,967         72
# 8         09-Jan-22                       8,204        6,275         17
# 9         10-Jan-22                   1,389,750      813,510      8,890
# 10        11-Jan-22                   1,302,609      786,542      9,403
# 11        12-Jan-22                   1,225,463      744,215      8,720
# ...

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.4

# %%
import torch
print(torch.__version__)
# Out:
# 1.7.0
